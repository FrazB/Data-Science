# %% [markdown]
# # Heading
# ## Sub heading
# ### Sub-subheading
# #### etc

# %% [markdown]
# images
#
# ![title](images/header.png "banner image")

# %% [markdown]
# Latex
#
# $
# \begin{eqnarray}
# \nabla \cdot \vec{B} &=& 0 \nonumber \\
# \nabla \times \vec{E} &=& - \frac{\partial B}{\partial t} \nonumber \\
# \nabla \times \vec{B} &=& \mu_{0}\vec{J} +
# \mu_{0}\epsilon_{0}\frac{\partial E}{\partial t}
# \end{eqnarray}
# $

# %% [markdown]
# <code style="background:yellow;color:black">Highlight, to grab attention.</code>

# %% [markdown]
# Tasks
#
# - [x] Some task
# - [ ] Some more task
#
# Bullets
#
# - First
# - second
#
# 1. Numbered
# 2. List

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Tip:</b> Use blue boxes (alert-info) for tips and notes.</div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Success:</b> This alert box indicates a successful or positive action.</div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Example:</b> Use yellow boxes for examples that are not inside code cells, or use for mathematical formulas if needed. Typically also used to display warning messages.</div>

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>Danger:</b> This alert box indicates a dangerous or potentially negative action.</div>

# %% [markdown]
# A table
#
# |Header|Header|Header|
# |:-|:-:|-:|
# |A     |B     |C     |
# |X     |Y     |Z     |
#
#
#
# ~~Scratch this~~

# %% [markdown]
# Geometric shapes
#
# &#9673;
# &#9638;

# %% [markdown]
# *This is bold text*
# **This is bold text**
# ***This is Bolditalic***
#
# <span style="color:red">Coloured Text</span>

# %% [markdown]
# [click me](https://en.wikipedia.org "Wikipedia"

# %% [markdown]
# ---
#
# ***

# %% [markdown]
# Having syntax highlighting in markdown
#
# ```python
# s = "Python syntax highlighting"
# print s
# ```

# %% [markdown]
# Make it look like a terminal
#
# <p style="background:black">
# <code style="background:black;color:white">C:\Users\YOUR_USERNAME> pip3 install roughviz
# </code>
# </p>

# %% [markdown]
# > some text
# >> and then some more text
# >>> and then some more

# %% [markdown]
# [Link to  sub heading](#Sub-heading)
